# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("SaaS-Sales.csv")
df
# Out:
#       Row ID          Order ID  Order Date  Date Key       Contact Name  \
# 0          1  EMEA-2022-152156   11/9/2022  20221109        Nathan Bell
# 1          2  EMEA-2022-152156   11/9/2022  20221109        Nathan Bell
# 2          3  AMER-2022-138688   6/13/2022  20220613     Deirdre Bailey
# 3          4  EMEA-2021-108966  10/11/2021  20211011         Zoe Hodges
# 4          5  EMEA-2021-108966  10/11/2021  20211011         Zoe Hodges
# ...      ...               ...         ...       ...                ...
# 9989    9990  EMEA-2020-110422   1/22/2020  20200122          Dan Allan
# 9990    9991  AMER-2023-121258   2/27/2023  20230227  Anthony Sanderson
# 9991    9992  AMER-2023-121258   2/27/2023  20230227  Anthony Sanderson
# 9992    9993  AMER-2023-121258   2/27/2023  20230227  Anthony Sanderson
# 9993    9994  AMER-2023-119914    5/5/2023  20230505   Jasmine Springer
#
#             Country           City Region Subregion           Customer  \
# ...

# %%
df.describe()
# Out:
#             Row ID      Date Key  Customer ID         Sales     Quantity  \
# count  9994.000000  9.994000e+03  9994.000000   9994.000000  9994.000000
# mean   4997.500000  2.021803e+07  1049.771963    229.858001     3.789574
# std    2885.163629  1.123898e+04    29.719388    623.245101     2.225110
# min       1.000000  2.020010e+07  1001.000000      0.444000     1.000000
# 25%    2499.250000  2.021052e+07  1024.000000     17.280000     2.000000
# 50%    4997.500000  2.022063e+07  1049.000000     54.490000     3.000000
# 75%    7495.750000  2.023052e+07  1076.000000    209.940000     5.000000
# max    9994.000000  2.023123e+07  1101.000000  22638.480000    14.000000
#
#           Discount       Profit
# count  9994.000000  9994.000000
# mean      0.156203    28.656896
# std       0.206452   234.260108
# min       0.000000 -6599.978000
# 25%       0.000000     1.728750
# 50%       0.200000     8.666500
# 75%       0.200000    29.364000
# max       0.800000  8399.976000

# %%
df.isnull().sum()
# Out:
# Row ID          0
# Order ID        0
# Order Date      0
# Date Key        0
# Contact Name    0
# Country         0
# City            0
# Region          0
# Subregion       0
# Customer        0
# Customer ID     0
# Industry        0
# Segment         0
# Product         0
# License         0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Row ID          9994
# Order ID        5009
# Order Date      1237
# Date Key        1237
# Contact Name     793
# Country           48
# City             262
# Region             3
# Subregion         12
# Customer          99
# Customer ID       99
# Industry          10
# Segment            3
# Product           14
# License         9994
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
from scipy.stats import shapiro

# %%
shapiro(df["Sales"])
# Out:
# c:\Users\Nitro 5\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 9994.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=0.32332715724629535, pvalue=4.065053524283138e-105)

# %%
shapiro(df["Profit"])
# Out:
# c:\Users\Nitro 5\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 9994.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=0.25709707779832647, pvalue=1.6987856431860357e-107)

# %%
df["Order Date"] = pd.DatetimeIndex(df["Order Date"])
df.head()
# Out:
#    Row ID          Order ID Order Date  Date Key    Contact Name  \
# 0       1  EMEA-2022-152156 2022-11-09  20221109     Nathan Bell
# 1       2  EMEA-2022-152156 2022-11-09  20221109     Nathan Bell
# 2       3  AMER-2022-138688 2022-06-13  20220613  Deirdre Bailey
# 3       4  EMEA-2021-108966 2021-10-11  20211011      Zoe Hodges
# 4       5  EMEA-2021-108966 2021-10-11  20211011      Zoe Hodges
#
#          Country           City Region Subregion           Customer  \
# 0        Ireland         Dublin   EMEA      UKIR            Chevron
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#    Customer ID Industry    Segment                 Product     License  \
# 0         1017   Energy        SMB         Marketing Suite  16GRM07R1K
# ...

# %%
upper = df["Profit"].mean() + 3*df["Profit"].std()
lower = df["Profit"].mean() - 3*df["Profit"].std()
upper, lower
# Out:
# (731.4372193806574, -674.1234267650881)

# %%
sns.boxplot(
    data=df,
    x="Profit",
    y="Order Date"    
)
#penampilan outlier
# Out:
# <Axes: xlabel='Profit', ylabel='Order Date'>

# %%
newdf = df.copy()
newdf.loc[(newdf["Profit"]>upper), "Profit"] = upper
newdf.loc[(newdf["Profit"]<lower), "Profit"] = lower

# %%
sns.boxplot(
    data=newdf,
    x="Profit",
    y="Order Date"    
)
#Tanpa Outlier
# Out:
# <Axes: xlabel='Profit', ylabel='Order Date'>

# %%
upperS = df["Sales"].mean() + 3*df["Sales"].std()
lowerS = df["Sales"].mean() - 3*df["Sales"].std()
upperS, lowerS
# Out:
# (2099.593302356544, -1639.877300695547)

# %%
df.loc[(df["Sales"] > upperS) | (df["Sales"] < lowerS)]
#jumlah outlier sales
# Out:
#       Row ID          Order ID Order Date  Date Key      Contact Name  \
# 27        28  EMEA-2021-150630 2021-09-17  20210917         Neil Gill
# 165      166   APJ-2020-139892 2020-09-08  20200908  Melanie Davidson
# 251      252  AMER-2022-145625 2022-09-12  20220912     Penelope Nash
# 262      263   APJ-2020-106992 2020-09-19  20200919      Charles Hart
# 263      264   APJ-2020-106992 2020-09-19  20200919      Charles Hart
# ...      ...               ...        ...       ...               ...
# 9741    9742  EMEA-2021-117086 2021-11-08  20211108      Pippa Hunter
# 9774    9775   APJ-2020-169019 2020-07-26  20200726         Lily Bond
# 9857    9858  AMER-2021-164301 2021-03-26  20210326      Dominic Hill
# 9929    9930  AMER-2022-129630 2022-09-05  20220905        Boris Reid
# 9948    9949   APJ-2023-121559 2023-06-02  20230602     Harry McGrath
#
#             Country         City Region Subregion                   Customer  \
# ...

# %%
sns.lineplot(
    data=newdf,
    x="Order Date",
    y="Sales"    
)
#sales dengan outlier
# Out:
# <Axes: xlabel='Order Date', ylabel='Sales'>

# %%
newdf.loc[(newdf["Sales"]>upperS), "Sales"] = upperS
newdf.loc[(newdf["Sales"]<lowerS), "Sales"] = lowerS

# %%
sns.lineplot(
    data=newdf,
    x="Order Date",
    y="Sales"    
)
#sales tanpa outlier
# Out:
# <Axes: xlabel='Order Date', ylabel='Sales'>

# %%
sns.boxplot(
    data=newdf,
    x="Profit",
    y="Order Date"    
)
#Tanpa Outlier
# Out:
# <Axes: xlabel='Profit', ylabel='Order Date'>

# %%
newdf.to_csv("New_SaaS_2.csv")
